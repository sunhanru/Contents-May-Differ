# %%
import glob, os
import csv
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#1000 epochs, depth = 3 layers, learning rate = 0.0001 
#Loss function = CrossEntropyLoss
#Width = 500
XYXY = np.genfromtxt('XYXY.csv', delimiter=',')
XYXY2 = np.genfromtxt('XYXY2.csv', delimiter=',')
XYXY3 = np.genfromtxt('XYXY3.csv', delimiter=',')
XYXY10 = np.genfromtxt('XYXY10.csv', delimiter=',')
#XYXYLP = np.genfromtxt('XYXYLP.csv', delimiter=',')
#XYXYDLP = np.genfromtxt('XYXYDLP.csv', delimiter=',')
#D = np.genfromtxt('D.csv', delimiter=',')
#DtimesLP = np.genfromtxt('DtimesLP.csv', delimiter=',')
#XYXYDLP = np.genfromtxt('XYXYDLP.csv', delimiter=',')

plt.figure(figsize=(12,8))
plt.plot(XYXY[:,0], XYXY[:,4], label='1 relative coordinate')
plt.plot(XYXY2[:,0], XYXY2[:,4], label='2 relative coordinates')
plt.plot(XYXY3[:,0], XYXY3[:,4], label='3 relative coordinates')
plt.plot(XYXY10[:,0], XYXY10[:,4], label='10 relative coordinates')
#plt.plot(XYXYLP[:,0], XYXYLP[:,4], label='XYXYLP')
#plt.plot(XYXYDLP[:,0], XYXYDLP[:,4], label='XYXYDLP')
#plt.plot(D[:,0], D[:,4], label='D')
#plt.plot(DtimesLP[:,0], DtimesLP[:,4], label='DtimesLP')


plt.legend(loc="lower right")
plt.title("DNN Training with relative XYXY coordinates (ReLU, Width=500)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy on Test Set")
plt.ylim([0,0.7])
plt.show()

# %%
XYXY3[:,4].max()
# Out:
# 0.6370614171028137
